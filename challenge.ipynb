# %%
# challenge.py: Python program to calculate challenge ranking of golf games
# Copyright (C) 2017 Pieter Kempeneers

# challenge.py is free software: you can redistribute it and/or modify
# it under the terms of the GNU General Public License as published by
# the Free Software Foundation, either version 3 of the License, or
# (at your option) any later version.

# challenge.py is distributed in the hope that it will be useful,
# but WITHOUT ANY WARRANTY; without even the implied warranty of
# MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.  See the
# GNU General Public License for more details.

# You should have received a copy of the GNU General Public License
# along with challenge.py.  If not, see <http://www.gnu.org/licenses/>.

# %%
import csv
import os
import heapq
from collections import defaultdict
import argparse

indir='.'
ext='csv'
player='Player'
score='Net Stable'
delimiter=';'
output=None

parser=argparse.ArgumentParser()
parser.add_argument("-indir","--indir",help="Path of the input directory containing the csv files",dest="indir",required=False,type=str,default=indir)
parser.add_argument("-ext","--ext",help="Extension of csv files",dest="ext",required=False,type=str,default=ext)
parser.add_argument("-delimiter","--delimiter",help="Delimiter for colums",dest="delimiter",required=False,type=str,default=delimiter)
parser.add_argument("-player","--player",help="Column name for player",dest="player",required=False,type=str,default=player)
parser.add_argument("-score","--score",help="Column name for score",dest="score",required=False,type=str,default=score)
parser.add_argument("-output","--output",help="Output filename with challenge ranking (leave empty to print on screen)",dest="output",required=False,type=str,default=output)

args = parser.parse_args()
indir=args.indir
ext=args.ext
delimiter=args.delimiter
player=args.player
score=args.score
output=args.output
    
netScores = defaultdict(list)
top5={}
    
for filename in os.listdir(indir):
    if filename.endswith(ext):
        with open(os.path.join(indir,filename), "r", encoding="ISO-8859-1") as csvfile:
            readCSV = csv.DictReader(csvfile,delimiter=delimiter)
            for row in readCSV:
                #print(row)
                if row[score]:
                    netScores[row[player]].append(int(row[score]))
        continue
    else:
        continue

for name in netScores:
    if len(netScores[name])>=3:
        #print(name,sum(netScores[name]))
        #totalScore[name]+=sum(netScores[name])
        top5[name]=sum(heapq.nlargest(5,netScores[name]))

top5_sorted=sorted(top5, key=top5.get,reverse=True)

if output:
    with open(output,"w") as outputf:
        for name in top5_sorted:
            #print(name,top5[name])    
            outputf.write("{},{}\n".format(name,top5[name]))
else:
    for name in top5_sorted:
        print(name,top5[name])
# Out:
# Argument parser failed, using default values
# indir: wedstrijden
# ext: csv
# player column: Player
# score column: Net Stable
# column delimiter: ;
# output: None
# BOONEN WIM (GOLFCLUB NUCLEA ) 207
# DE BLIECK FRANK (GOLFCLUB NUCLEA ) 204
# VAN GRIEKEN PAUL (GOLFCLUB NUCLEA ) 201
# KEMPS WENDY (GOLFCLUB NUCLEA ) 198
# ROOSEN LUCIEN (GOLFCLUB NUCLEA ) 192
# KEMPEN KRISTOF (GOLFCLUB NUCLEA ) 191
# PIRARD SILVIA  (GOLFCLUB NUCLEA ) 190
# AERTS HERMAN (GOLFCLUB NUCLEA ) 189
# DIERCKX HAN (GOLFCLUB NUCLEA ) 189
# BOELS DIRK  (GOLFCLUB NUCLEA ) 188
# HUYSMANS FLOR  (GOLFCLUB NUCLEA ) 188
# STERCKX RAF (GOLFCLUB NUCLEA ) 187
# ALEX CONSTANTIN (GOLFCLUB NUCLEA ) 186
# JANSSENS DIRK (GOLFCLUB NUCLEA ) 186
# LIEVENS LUC (GOLFCLUB NUCLEA ) 186
# KUIJPERS PETER (GOLFCLUB NUCLEA ) 186
# BOSMANS MARLEEN (GOLFCLUB NUCLEA ) 185
# GEENTJENS KRIS (GOLFCLUB NUCLEA ) 185
# WOUTERS GEORGES (GOLFCLUB NUCLEA ) 184
# NEVELSTEEN JEF (GOLFCLUB NUCLEA ) 184
# BOECKX HERMAN (GOLFCLUB NUCLEA ) 184
# WILMS JOZEF (GOLFCLUB NUCLEA ) 183
# CAEYERS TONY (GOLFCLUB NUCLEA ) 183
# MOERKENS KRIS (GOLFCLUB NUCLEA ) 183
# GEERINGHS IDA (GOLFCLUB NUCLEA ) 182
# JACOBS LELIANNE  (GOLFCLUB NUCLEA ) 182
# VAN VLERKEN MARJON (GOLFCLUB NUCLEA ) 182
# VAN LAERHOVEN MICHEL (GOLFCLUB NUCLEA ) 182
# SAS LISETTE (GOLFCLUB NUCLEA ) 181
# MICHAT MICHELINE (GOLFCLUB NUCLEA ) 181
# LENAERTS WILLY (GOLFCLUB NUCLEA ) 181
# CHARLIER MIEKE (GOLFCLUB NUCLEA ) 181
# LIEVENS MICHEL (GOLFCLUB NUCLEA ) 180
# VERBRAEKEN PATRICK (GOLFCLUB NUCLEA ) 180
# VAN GILS JEAN (GOLFCLUB NUCLEA ) 180
# DE RUDDER OLIVIER (GOLFCLUB NUCLEA ) 179
# RIJNHOUT BERTINE (GOLFCLUB NUCLEA ) 178
# BERBEN ANNE-MARIE (GOLFCLUB NUCLEA ) 177
# VERBRUGGEN GUY (GOLFCLUB NUCLEA ) 177
# AERTS MIEL (GOLFCLUB NUCLEA ) 177
# BROUGMANS VALÈRE (GOLFCLUB NUCLEA ) 176
# OEYEN WILLY  (GOLFCLUB NUCLEA ) 176
# VERBRUGGEN-VENNEKENS ODETTE (GOLFCLUB NUCLEA ) 176
# BLUEKENS BOB (GOLFCLUB NUCLEA ) 176
# VERAGHTERT GERRY (GOLFCLUB NUCLEA ) 175
# KORTSEN NIELS-HENRIK (GOLFCLUB NUCLEA ) 175
# VERBUNT-VANHELLEMONT BIRGIT (GOLFCLUB NUCLEA ) 174
# VAN DER HARST JOOP (GOLFCLUB NUCLEA ) 174
# VANHEUCKELOM WIM (GOLFCLUB NUCLEA ) 173
# HOUBEN STEF (GOLFCLUB NUCLEA ) 173
# WALS PETRA (GOLFCLUB NUCLEA ) 173
# NUYTS GUST (GOLFCLUB NUCLEA ) 172
# DE VEL MICHEL (GOLFCLUB NUCLEA ) 172
# WUYTS RIK (GOLFCLUB NUCLEA ) 171
# GOOS LINDA (GOLFCLUB NUCLEA ) 171
# CORNELIS GUY (GOLFCLUB NUCLEA ) 170
# SPIRLET-VAN KEYMEULEN YANNICK (GOLFCLUB NUCLEA ) 170
# CEUSTERS JEF (GOLFCLUB NUCLEA ) 170
# BOONEN HUGO (GOLFCLUB NUCLEA ) 170
# LANGELAND HENK (GOLFCLUB NUCLEA ) 169
# VAN LIEROP HANS (GOLFCLUB NUCLEA ) 169
# MICHIELS STEPHAN (GOLFCLUB NUCLEA ) 169
# BERGHMANS ANNE (GOLFCLUB NUCLEA ) 169
# VANGENECHTEN  RONNY (GOLFCLUB NUCLEA ) 168
# VAN LEIDEN JACOB (GOLFCLUB NUCLEA ) 168
# FRIJTERS FONS (GOLFCLUB NUCLEA ) 168
# DE VEL-VANDERLINDEN MARIA (GOLFCLUB NUCLEA ) 168
# VERBRUGGEN ANDRÉ (GOLFCLUB NUCLEA ) 167
# RUPPOL GREET (GOLFCLUB NUCLEA ) 167
# BINNEMANS TONNY (GOLFCLUB NUCLEA ) 167
# KUIJPERS-HESIUS JEANNINE (GOLFCLUB NUCLEA ) 167
# JACOBS LUC (GOLFCLUB NUCLEA ) 166
# KERCKHOVE GIOVANI (GOLFCLUB NUCLEA ) 166
# PEETERS CARL (GOLFCLUB NUCLEA ) 166
# CHANG SUZANNE (GOLFCLUB NUCLEA ) 166
# DHONDT GUIDO (GOLFCLUB NUCLEA ) 165
# BRANDINI BLAISE (GOLFCLUB NUCLEA ) 165
# JANSSENS ELS (GOLFCLUB NUCLEA ) 164
# GIELEN BRIGITTE  (GOLFCLUB NUCLEA ) 163
# VERBIST CHANTAL (GOLFCLUB NUCLEA ) 163
# VERHOEVEN WERNER (GOLFCLUB NUCLEA ) 162
# KEUTEN HUGO (GOLFCLUB NUCLEA ) 160
# VANKEERBERGHEN MARC (GOLFCLUB NUCLEA ) 160
# VAN BAELEN GUY (KEMPENSE GOLF CLUB ) 158
# SNOEKS LUC (GOLFCLUB NUCLEA ) 157
# MICHEL RIK (GOLFCLUB NUCLEA ) 156
# WATTECAMPS ERIC (GOLFCLUB NUCLEA ) 156
# PLESSERS-RUYSBERGH HILDE (GOLFCLUB NUCLEA ) 155
# HANNES LAURA (GOLFCLUB NUCLEA ) 155
# GODELAINE HERWIG (GOLFCLUB NUCLEA ) 154
# BAKEN HARRY (GOLFCLUB NUCLEA ) 153
# VERMIJL JOS (GOLFCLUB NUCLEA ) 153
# LYCKE WILLY (GOLFCLUB NUCLEA ) 152
# MERMANS MARGO (GOLFCLUB NUCLEA ) 152
# VANGEEL FRANKIE (GOLFCLUB NUCLEA ) 151
# GEVERS RIA (GOLFCLUB NUCLEA ) 151
# WAUMANS POL (GOLFCLUB NUCLEA ) 151
# VAN HOOLST MARIA  (GOLFCLUB NUCLEA ) 151
# BAKEN HANN (GOLFCLUB NUCLEA ) 150
# BULCKENS GREET (GOLFCLUB NUCLEA ) 150
# HUYS LEEN (GOLFCLUB NUCLEA ) 150
# MICHIELSEN JOHAN (GOLFCLUB NUCLEA ) 149
# WENS LIESBETH (GOLFCLUB NUCLEA ) 149
# HART PETER (GOLFCLUB NUCLEA ) 148
# HULSMANS PAUL (GOLFCLUB NUCLEA ) 147
# PLESSERS JOS (GOLFCLUB NUCLEA ) 146
# BERGEN HARRY (GOLFCLUB NUCLEA ) 146
# RIJNHOUT PAUL (GOLFCLUB NUCLEA ) 145
# VAN DER LINDEN HANS (GOLFCLUB NUCLEA ) 143
# VAN DE CRUYS MARC (GOLFCLUB NUCLEA ) 143
# VAN LIEROP TREES (GOLFCLUB NUCLEA ) 142
# MERTENS FONS (GOLFCLUB NUCLEA ) 142
# LAMBIET CLAUDE (GOLFCLUB NUCLEA ) 141
# DOCKX ESTHER (GOLFCLUB NUCLEA ) 139
# JANSSENS MARC (GOLFCLUB NUCLEA ) 138
# JACOBS JAN  (GOLFCLUB NUCLEA ) 138
# PEETERMANS WALTER (GOLFCLUB NUCLEA ) 137
# MEYNENDONCKX GUNTER (GOLFCLUB NUCLEA ) 137
# VERSTRATEN JAN-WILLEM (GOLFCLUB NUCLEA ) 137
# LUTS PATRICK (GOLFCLUB NUCLEA ) 136
# EYCKMANS KIM (GOLFCLUB NUCLEA ) 135
# VERWIMP JOHAN (GOLFCLUB NUCLEA ) 131
# MORREN ROBBY  (GOLFCLUB NUCLEA ) 131
# HAM AD (GOLFCLUB NUCLEA ) 131
# HAAGEN LINDA  (GOLFCLUB NUCLEA ) 131
# BERGHMANS SONJA (GOLFCLUB NUCLEA ) 130
# DE PROOST KOEN (GOLFCLUB NUCLEA ) 130
# JAMAR MADY (GOLFCLUB NUCLEA ) 129
# LAENEN IRENE (GOLFCLUB NUCLEA ) 126
# VERMIJL MARJOLEIN (GOLFCLUB NUCLEA ) 125
# VAN DEN EYNDE LOUIS  (GOLFCLUB NUCLEA ) 124
# DRENT IVO  (GOLFCLUB NUCLEA ) 124
# GEENEN GUIDO (KEMPENSE GOLF CLUB ) 124
# KOK GERRIT-JOH (GOLFCLUB NUCLEA ) 121
# AERTS GEERT (GOLFCLUB NUCLEA ) 118
# LAUWERS BEA (GOLFCLUB NUCLEA ) 117
# POELS KOEN (GOLFCLUB NUCLEA ) 114
# DIELIS SIMONE (KEMPENSE GOLF CLUB ) 111
# MERMANS JOS (GOLFCLUB NUCLEA ) 111
# VANDAMME GREET (GOLFCLUB NUCLEA ) 110
# DERAEMAEKER LUC (GOLFCLUB NUCLEA ) 108
# SWERTS KARIN (GOLFCLUB NUCLEA ) 106
# NOUWEN LEO (KEMPENSE GOLF CLUB ) 105
# VERVECKEN MARC (GOLFCLUB NUCLEA ) 104
# SELS LUCY (MILLENNIUM GOLF) 103
# VAN BAELEN RUDI (KEMPENSE GOLF CLUB ) 102
# VAN WERDE JO (GOLFCLUB NUCLEA ) 99
# GEUENS VALERIE (GOLFCLUB NUCLEA ) 98
# CAVENTS YVES (GOLFCLUB NUCLEA ) 97
# VAN BAELEN DIRK (GOLFCLUB NUCLEA ) 91
# KORTSEN ROBIN (GOLFCLUB NUCLEA ) 90
# DAEMEN SEBASTIAAN (GOLFCLUB NUCLEA ) 89
# GEYPEN DANIELLE (GOLFCLUB NUCLEA ) 85
# VERBUNT FRANS (GOLFCLUB NUCLEA ) 84
# CLAES PATRICK (GOLFCLUB NUCLEA ) 83
# DE BLIECK ESTELLE (GOLFCLUB NUCLEA ) 67
# CUYPERS BEN (GOLFCLUB NUCLEA ) 67
# KESSELAERS MAARTEN (GOLFCLUB NUCLEA ) 60
# GEYPEN MARCELINE (GOLFCLUB NUCLEA ) 29
# WYERS MARK (GOLFCLUB NUCLEA ) 22
# usage: ipykernel_launcher.py [-h] [-indir INDIR] [-ext EXT]
#                              [-delimiter DELIMITER] [-player PLAYER]
#                              [-score PLAYER] [-output OUTPUT]
# ipykernel_launcher.py: error: unrecognized arguments: -f /run/user/1000/jupyter/kernel-f4ba8be5-175a-4018-bfde-136a886dfccf.json
